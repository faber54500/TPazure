# %% [markdown]
# # Importation et vérification des valeurs nulles

# %%
import pandas as pd
import numpy as np 
# Chemin du fichier source
fichier_source = r"C:\Users\Etudiant\Desktop\Cours\cloud\enregistrement_github\synthetic_health_lifestyle_dataset.csv"

# Chargement du CSV
df = pd.read_csv(fichier_source)
print(df.shape)  # pour voir combien de lignes/colonnes
print(df.head())
print(df.isnull().sum())
# Out:
# (7500, 13)
#    ID  Age  Gender  Height_cm  Weight_kg   BMI Smoker   Exercise_Freq  \
# 0   1   56   Other      177.6       37.3  11.8    Yes             NaN
# 1   2   69   Other      169.3       70.7  24.7     No  1-2 times/week
# 2   3   46  Female      159.1       69.0  27.3     No           Daily
# 3   4   32    Male      170.6       76.4  26.3     No  3-5 times/week
# 4   5   60    Male      158.4       60.4  24.1     No  3-5 times/week
#
#   Diet_Quality Alcohol_Consumption Chronic_Disease  Stress_Level  Sleep_Hours
# 0         Poor                 NaN              No             9          8.5
# 1         Good                High              No             2          5.9
# 2    Excellent            Moderate              No             3          4.8
# 3    Excellent            Moderate              No             9          6.6
# 4    Excellent                 Low             Yes             6          6.1
# ID                        0
# Age                       0
# ...

# %%
print(df[df['Exercise_Freq'].isnull()].head())
print(df[df['Alcohol_Consumption'].isnull()].head())
# Out:
#     ID  Age  Gender  Height_cm  Weight_kg   BMI Smoker Exercise_Freq  \
# 0    1   56   Other      177.6       37.3  11.8    Yes           NaN
# 14  15   57   Other      169.8       78.0  27.1     No           NaN
# 18  19   19  Female      158.4       59.0  23.5    Yes           NaN
# 21  22   47    Male      174.0       55.8  18.4     No           NaN
# 22  23   55   Other      155.6       67.4  27.8     No           NaN
#
#    Diet_Quality Alcohol_Consumption Chronic_Disease  Stress_Level  Sleep_Hours
# 0          Poor                 NaN              No             9          8.5
# 14      Average                High              No             6          8.0
# 18         Poor            Moderate              No            10          3.6
# 21         Poor                 Low              No            10          7.9
# 22    Excellent                High              No             9          7.3
#     ID  Age  Gender  Height_cm  Weight_kg   BMI Smoker   Exercise_Freq  \
# ...

# %%
print(df.columns.tolist())
# Out:
# ['ID', 'Age', 'Gender', 'Height_cm', 'Weight_kg', 'BMI', 'Smoker', 'Exercise_Freq', 'Diet_Quality', 'Alcohol_Consumption', 'Chronic_Disease', 'Stress_Level', 'Sleep_Hours']

# %%
df.describe
# Out:
# <bound method NDFrame.describe of         ID  Age  Gender  Height_cm  Weight_kg   BMI Smoker   Exercise_Freq  \
# 0        1   56   Other      177.6       37.3  11.8    Yes             NaN
# 1        2   69   Other      169.3       70.7  24.7     No  1-2 times/week
# 2        3   46  Female      159.1       69.0  27.3     No           Daily
# 3        4   32    Male      170.6       76.4  26.3     No  3-5 times/week
# 4        5   60    Male      158.4       60.4  24.1     No  3-5 times/week
# ...    ...  ...     ...        ...        ...   ...    ...             ...
# 7495  7496   55   Other      168.3       52.4  18.5    Yes  1-2 times/week
# 7496  7497   24    Male      179.1       58.8  18.3     No  3-5 times/week
# 7497  7498   61   Other      160.2       80.0  31.2     No  3-5 times/week
# 7498  7499   40  Female      172.6       66.1  22.2     No  1-2 times/week
# 7499  7500   58   Other      163.8       59.3  22.1     No           Daily
#
# ...

# %%
df.dtypes
# Out:
# ID                       int64
# Age                      int64
# Gender                  object
# Height_cm              float64
# Weight_kg              float64
# BMI                    float64
# Smoker                  object
# Exercise_Freq           object
# Diet_Quality            object
# Alcohol_Consumption     object
# Chronic_Disease         object
# Stress_Level             int64
# Sleep_Hours            float64
# dtype: object

# %% [markdown]
# # Vérification des valeurs nulles

# %%
df.isnull().sum()
# Out:
# ID                        0
# Age                       0
# Gender                    0
# Height_cm                 0
# Weight_kg                 0
# BMI                       0
# Smoker                    0
# Exercise_Freq          1879
# Diet_Quality              0
# Alcohol_Consumption    1892
# Chronic_Disease           0
# Stress_Level              0
# Sleep_Hours               0
# dtype: int64

# %% [markdown]
# # Vérification des valeurs uniques et remplacement par des valeurs numériques

# %%
df['Gender'].unique()
# Out:
# array(['Other', 'Female', 'Male'], dtype=object)

# %%
df['Smoker'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df['Exercise_Freq'].unique()
# Out:
# array([nan, '1-2 times/week', 'Daily', '3-5 times/week'], dtype=object)

# %%
df['Diet_Quality'].unique()
# Out:
# array(['Poor', 'Good', 'Excellent', 'Average'], dtype=object)

# %%
df['Alcohol_Consumption'].unique()
# Out:
# array([nan, 'High', 'Moderate', 'Low'], dtype=object)

# %%
df['Chronic_Disease'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df['Stress_Level'].unique()
# Out:
# array([ 9,  2,  3,  6,  1,  7, 10,  4,  5,  8], dtype=int64)

# %%
df['Sleep_Hours'].unique()
# Out:
# array([ 8.5,  5.9,  4.8,  6.6,  6.1,  5.8,  6.8,  6.3,  5.6,  9.7,  7.7,
#         7.2,  6.9,  8. ,  7.8,  5.4,  4.7,  3.6,  7.9,  7.3,  8.4,  5. ,
#         6.5,  4.6,  5.7,  5.2,  8.3,  3.9,  6. ,  7.5,  9.2,  4.4,  5.5,
#         5.3,  9. ,  8.6,  4.9,  8.2,  6.2, 10.2,  6.7,  7.1,  5.1,  4.2,
#         7. ,  8.9, 10. ,  8.7,  9.8,  7.6,  7.4,  8.1,  8.8, 10.3,  6.4,
#         9.3,  9.4,  9.5,  9.6, 10.1,  3.7,  9.1, 10.6, 10.7,  3.8,  2.1,
#        10.8,  4. ,  4.5, 11.3,  4.3,  4.1,  3.5,  3.3, 10.5,  9.9, 11. ,
#        11.6, 10.4, 10.9,  3.1,  3. , 11.2,  2.4,  2.9,  3.4, 11.5,  3.2,
#        11.4, 12.1,  2.6,  2.5,  2. ,  2.7, 11.1, 12.6,  1.9,  2.2,  2.8,
#        11.7, 11.8,  2.3])

# %%
df['Smoker']=df['Smoker'].replace({'Yes':1, 'No':0})
df['Diet_Quality']=df['Diet_Quality'].replace({'Poor':0, 'Good':2, 'Excellent':3, 'Average':1})
df['Chronic_Disease']=df['Chronic_Disease'].replace({'Yes':1, 'No':0})
# Out:
# C:\Users\Etudiant\AppData\Local\Temp\ipykernel_12864\4165922202.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Smoker']=df['Smoker'].replace({'Yes':1, 'No':0})
# C:\Users\Etudiant\AppData\Local\Temp\ipykernel_12864\4165922202.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Diet_Quality']=df['Diet_Quality'].replace({'Poor':0, 'Good':2, 'Excellent':3, 'Average':1})
# ...

# %%
# Remplacement des NaN par '0' (string)
df['Alcohol_Consumption'] = df['Alcohol_Consumption'].fillna('0')

# Puis remplacement des catégories par des entiers
df['Alcohol_Consumption'] = df['Alcohol_Consumption'].replace({
    '0': 0,
    'Low': 1,
    'High': 3,
    'Moderate': 2
})
# Out:
# C:\Users\Etudiant\AppData\Local\Temp\ipykernel_12864\2847530903.py:5: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Alcohol_Consumption'] = df['Alcohol_Consumption'].replace({

# %%
df['Smoker'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
df['Exercise_Freq'].unique()
# Out:
# array([nan, '1-2 times/week', 'Daily', '3-5 times/week'], dtype=object)

# %%
df['Diet_Quality'].unique()
# Out:
# array([0, 2, 3, 1], dtype=int64)

# %%
df['Alcohol_Consumption'].unique()
# Out:
# array([0, 3, 2, 1], dtype=int64)

# %%
df['Chronic_Disease'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
print(df['Exercise_Freq'].unique())
# Out:
# [nan '1-2 times/week' 'Daily' '3-5 times/week']

# %%
# D’abord remplacer les NaN par '0' (string)
df['Exercise_Freq'] = df['Exercise_Freq'].fillna('0')

# Puis remplacer les catégories par des entiers
df['Exercise_Freq'] = df['Exercise_Freq'].replace({
    '0': 0,
    '1-2 times/week': 1,
    'Daily': 3,
    '3-5 times/week': 2
})
# Out:
# C:\Users\Etudiant\AppData\Local\Temp\ipykernel_12864\726819000.py:5: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Exercise_Freq'] = df['Exercise_Freq'].replace({

# %%
df['Exercise_Freq'].unique()
# Out:
# array([0, 1, 3, 2], dtype=int64)

# %% [markdown]
# # Classement heure de sommeil par catégorie

# %%
def classer_sommeil(h):
    if h < 4:
        return 'Très peu'
    elif 4 <= h < 6:
        return 'Peu'
    elif 6 <= h < 8:
        return 'Moyen'
    else:
        return 'Beaucoup'

df['Sleep_Category'] = df['Sleep_Hours'].apply(classer_sommeil)

print(df[['Sleep_Hours', 'Sleep_Category']].head())
# Out:
#    Sleep_Hours Sleep_Category
# 0          8.5       Beaucoup
# 1          5.9            Peu
# 2          4.8            Peu
# 3          6.6          Moyen
# 4          6.1          Moyen

# %% [markdown]
# # On verifie si il n'y a plus de valeur nul

# %%
df.isnull().sum()
# Out:
# ID                     0
# Age                    0
# Gender                 0
# Height_cm              0
# Weight_kg              0
# BMI                    0
# Smoker                 0
# Exercise_Freq          0
# Diet_Quality           0
# Alcohol_Consumption    0
# Chronic_Disease        0
# Stress_Level           0
# Sleep_Hours            0
# Sleep_Category         0
# dtype: int64

# %%
print(df.head())
# Out:
#    ID  Age  Gender  Height_cm  Weight_kg   BMI  Smoker  Exercise_Freq  \
# 0   1   56   Other      177.6       37.3  11.8       1              0
# 1   2   69   Other      169.3       70.7  24.7       0              1
# 2   3   46  Female      159.1       69.0  27.3       0              3
# 3   4   32    Male      170.6       76.4  26.3       0              2
# 4   5   60    Male      158.4       60.4  24.1       0              2
#
#    Diet_Quality  Alcohol_Consumption  Chronic_Disease  Stress_Level  \
# 0             0                    0                0             9
# 1             2                    3                0             2
# 2             3                    2                0             3
# 3             3                    2                0             9
# 4             3                    1                1             6
#
#    Sleep_Hours Sleep_Category
# 0          8.5       Beaucoup
# 1          5.9            Peu
# 2          4.8            Peu
# ...

# %% [markdown]
# # Classement IMC par catégorie

# %%
def classer_imc (imc):
    if imc < 16.5:
        return 'Dénutrition'
    elif 16.5 <= imc < 18.4:
        return 'Maigreur'
    elif 18.4 <= imc < 24.9:
        return 'Normal'
    elif 25 <= imc < 29.9:
        return 'Surpoids'
    elif 30 <= imc < 34.9:
        return 'Obésité classe 1'
    elif 35 <= imc < 39.9:
        return 'Obésité classe 2' 
    else:
        return 'Obésité classe 3'

df['IMC'] = df['BMI'].apply(classer_imc)

# %% [markdown]
# # On vérifie que le classement IMC par catégorie est bien pris en compte

# %%
print(df[['IMC', 'BMI']].head())
# Out:
#            IMC   BMI
# 0  Dénutrition  11.8
# 1       Normal  24.7
# 2     Surpoids  27.3
# 3     Surpoids  26.3
# 4       Normal  24.1

# %%
def classer_taille(taille):
    if taille < 155:
        return 'Très petit'
    elif 155 <= taille < 165:
        return 'Petit'
    elif 165 <= taille < 175:
        return 'Moyen'
    elif 175 <= taille < 185:
        return 'Grand'
    else:
        return 'Très grand'
        
df['Categorie_taille'] = df['Height_cm'].apply(classer_taille)

# %% [markdown]
# # On vérifie que le classement IMC par catégorie est bien pris en compte

# %%
print(df[['Height_cm', 'Categorie_taille']].head())
# Out:
#    Height_cm Categorie_taille
# 0      177.6            Grand
# 1      169.3            Moyen
# 2      159.1            Petit
# 3      170.6            Moyen
# 4      158.4            Petit

# %% [markdown]
# # On regarde l'intégralité de la table

# %%
print(df.head())
# Out:
#    ID  Age  Gender  Height_cm  Weight_kg   BMI  Smoker  Exercise_Freq  \
# 0   1   56   Other      177.6       37.3  11.8       1              0
# 1   2   69   Other      169.3       70.7  24.7       0              1
# 2   3   46  Female      159.1       69.0  27.3       0              3
# 3   4   32    Male      170.6       76.4  26.3       0              2
# 4   5   60    Male      158.4       60.4  24.1       0              2
#
#    Diet_Quality  Alcohol_Consumption  Chronic_Disease  Stress_Level  \
# 0             0                    0                0             9
# 1             2                    3                0             2
# 2             3                    2                0             3
# 3             3                    2                0             9
# 4             3                    1                1             6
#
#    Sleep_Hours Sleep_Category          IMC Categorie_taille
# 0          8.5       Beaucoup  Dénutrition            Grand
# ...

# %% [markdown]
# # Test pour déterminer si il y a une corrélation entre Chronic_Disease et les valeurs numérique
# # Si p-value < 0.05 → il y a un lien statistique entre la variable catégorielle et la présence de maladie chronique.

# %%
from scipy.stats import pointbiserialr

variables = ['Stress_Level', 'Diet_Quality', 'Alcohol_Consumption', 'Smoker', 'Exercise_Freq', 'Age']

for var in variables:
    corr, pval = pointbiserialr(df[var], df['Chronic_Disease'])
    print(f"{var} → Corrélation = {corr:.3f}, p-value = {pval:.4f}")
# Out:
# Stress_Level → Corrélation = 0.010, p-value = 0.3802
# Diet_Quality → Corrélation = -0.002, p-value = 0.8487
# Alcohol_Consumption → Corrélation = 0.001, p-value = 0.9233
# Smoker → Corrélation = -0.003, p-value = 0.8036
# Exercise_Freq → Corrélation = 0.001, p-value = 0.9226
# Age → Corrélation = 0.007, p-value = 0.5695

# %% [markdown]
# # Dans le cas présent il n'y a aucune relation linéaire entre 'Stress_Level', 'Diet_Quality', 'Alcohol_Consumption', 'Smoker', 'Exercise_Freq', 'Age' et la maladie chronique

# %% [markdown]
# # Test pour déterminer si il y a une corrélation entre Chronic_Disease et les valeurs catégorielles

# %%
from scipy.stats import chi2_contingency

cat_vars = ['IMC', 'Sleep_Category']

for var in cat_vars:
    table = pd.crosstab(df[var], df['Chronic_Disease'])
    chi2, p, dof, expected = chi2_contingency(table)
    print(f"{var} → Test du chi² : p-value = {p:.4f}")
# Out:
# IMC → Test du chi² : p-value = 0.3513
# Sleep_Category → Test du chi² : p-value = 0.5654

# %% [markdown]
# # Dans le cas présent il n'y a aucune relation linéaire entre 'IMC', 'Sleep_Category' et la maladie chronique

# %% [markdown]
# # test avec un model non linéaire avec random forest

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score
from sklearn.preprocessing import StandardScaler

features = ['Age', 'Stress_Level', 'Diet_Quality', 'Alcohol_Consumption',
            'Smoker', 'Exercise_Freq', 'Sleep_Hours']

X = df[features]
y = df['Chronic_Disease']

# Standardisation des variables numériques
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Séparation train/test
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Création et entraînement du modèle Random Forest
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_train)

# Prédictions
y_pred = rf_model.predict(X_test)
y_proba = rf_model.predict_proba(X_test)[:, 1]

# Évaluation du modèle
print("Classification Report:\n", classification_report(y_test, y_pred))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
print("AUC-ROC Score:", roc_auc_score(y_test, y_proba))

# Importance des variables
importances = rf_model.feature_importances_
feature_importance_df = pd.DataFrame({'Feature': features, 'Importance': importances})
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

print("\nImportance des variables :\n", feature_importance_df)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.80      0.98      0.88      1199
#            1       0.14      0.01      0.02       301
#
#     accuracy                           0.79      1500
#    macro avg       0.47      0.50      0.45      1500
# weighted avg       0.67      0.79      0.71      1500
#
# Confusion Matrix:
#  [[1175   24]
#  [ 297    4]]
# AUC-ROC Score: 0.5006954854405249
#
# Importance des variables :
#                 Feature  Importance
# 6          Sleep_Hours    0.310933
# 0                  Age    0.278188
# 1         Stress_Level    0.144725
# 3  Alcohol_Consumption    0.078730
# 2         Diet_Quality    0.078558
# 5        Exercise_Freq    0.078215
# 4               Smoker    0.030651

# %% [markdown]
# # Avec la matrice de confusion le modele à prédit 297 faux négatif le modèle dis qu'il ne sont pas malade mais ils sont malades
# # Le modèle n’est pas capable de discriminer les malades des non-malades.
# # On ne peut pas conclure sur des relations significatives

# %% [markdown]
# # Exportation du fichier transformé

# %%
df.to_csv("C:\\Users\\Etudiant\\Desktop\\Cours\\cloud\\enregistrement_github\\IMC.csv", index=False)

# %% [markdown]
# # Transformation du fichier pour clustering dans Azure Ai studio

# %%
print(df.head())
# Out:
#    ID  Age  Gender  Height_cm  Weight_kg   BMI  Smoker  Exercise_Freq  \
# 0   1   56   Other      177.6       37.3  11.8       1              0
# 1   2   69   Other      169.3       70.7  24.7       0              1
# 2   3   46  Female      159.1       69.0  27.3       0              3
# 3   4   32    Male      170.6       76.4  26.3       0              2
# 4   5   60    Male      158.4       60.4  24.1       0              2
#
#    Diet_Quality  Alcohol_Consumption  Chronic_Disease  Stress_Level  \
# 0             0                    0                0             9
# 1             2                    3                0             2
# 2             3                    2                0             3
# 3             3                    2                0             9
# 4             3                    1                1             6
#
#    Sleep_Hours Sleep_Category          IMC Categorie_taille
# 0          8.5       Beaucoup  Dénutrition            Grand
# ...

# %% [markdown]
# # Passage en numérique du genre

# %%
def genre(g):
    if g=='Male':
        return 0
    elif g=='Female': 
        return 1
    elif g=='Other':
        return 2 

df['Gender_category'] = df['Gender'].apply(genre)

print(df[['Gender_category', 'Gender']].head())
# Out:
#    Gender_category  Gender
# 0                2   Other
# 1                2   Other
# 2                1  Female
# 3                0    Male
# 4                0    Male

# %%
print (df.head())
# Out:
#    ID  Age  Gender  Height_cm  Weight_kg   BMI  Smoker  Exercise_Freq  \
# 0   1   56   Other      177.6       37.3  11.8       1              0
# 1   2   69   Other      169.3       70.7  24.7       0              1
# 2   3   46  Female      159.1       69.0  27.3       0              3
# 3   4   32    Male      170.6       76.4  26.3       0              2
# 4   5   60    Male      158.4       60.4  24.1       0              2
#
#    Diet_Quality  Alcohol_Consumption  Chronic_Disease  Stress_Level  \
# 0             0                    0                0             9
# 1             2                    3                0             2
# 2             3                    2                0             3
# 3             3                    2                0             9
# 4             3                    1                1             6
#
#    Sleep_Hours Sleep_Category          IMC Categorie_taille  Gender_category
# ...

# %% [markdown]
# # Suppression des colonnes non numériques et redondantes

# %%
df = df.drop (['ID','Gender', 'Sleep_Category', 'IMC', 'Categorie_taille','Height_cm','Weight_kg'], axis =1)
df = df.rename(columns={'BMI':'IMC'})
print (df.head())
# Out:
#    Age   IMC  Smoker  Exercise_Freq  Diet_Quality  Alcohol_Consumption  \
# 0   56  11.8       1              0             0                    0
# 1   69  24.7       0              1             2                    3
# 2   46  27.3       0              3             3                    2
# 3   32  26.3       0              2             3                    2
# 4   60  24.1       0              2             3                    1
#
#    Chronic_Disease  Stress_Level  Sleep_Hours  Gender_category
# 0                0             9          8.5                2
# 1                0             2          5.9                2
# 2                0             3          4.8                1
# 3                0             9          6.6                0
# 4                1             6          6.1                0

# %% [markdown]
# # Vérification qu'il n'y a que des valeurs numériques

# %%
df.dtypes
# Out:
# Age                      int64
# IMC                    float64
# Smoker                   int64
# Exercise_Freq            int64
# Diet_Quality             int64
# Alcohol_Consumption      int64
# Chronic_Disease          int64
# Stress_Level             int64
# Sleep_Hours            float64
# Gender_category          int64
# dtype: object

# %% [markdown]
# # Vérification qu'il n'y a pas de valeur nulle

# %%
df.isnull().sum()
# Out:
# Age                    0
# IMC                    0
# Smoker                 0
# Exercise_Freq          0
# Diet_Quality           0
# Alcohol_Consumption    0
# Chronic_Disease        0
# Stress_Level           0
# Sleep_Hours            0
# Gender_category        0
# dtype: int64

# %% [markdown]
# # Exportation du fichier transformé

# %%
df.to_csv("C:\\Users\\Etudiant\\Desktop\\Cours\\cloud\\sujet_a_rendre_web\\donnesantepourcluster.csv", index=False)

# %% [markdown]
# # Analyse du clustering après traitement sur Azure AI studio

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.set(style="whitegrid")
plt.rcParams["figure.figsize"] = (10, 6)

# %%
# Chemin du fichier source
fichier_sourcecluster = r"C:\Users\Etudiant\Desktop\Cours\cloud\sujet_a_rendre_web\clustersante.csv"

# Chargement du CSV
df = pd.read_csv(fichier_sourcecluster)

print(df.head())
# Out:
#         Age       IMC    Smoker  Exercise_Freq  Diet_Quality  \
# 0  0.828034 -2.212769  1.533853      -1.339692     -1.333820
# 1  1.699884 -0.207167 -0.651953      -0.450359      0.464266
# 2  0.157380  0.197063 -0.651953       1.328309      1.363309
# 3 -0.781535  0.041590 -0.651953       0.438975      1.363309
# 4  1.096295 -0.300451 -0.651953       0.438975      1.363309
#
#    Alcohol_Consumption  Chronic_Disease  Stress_Level  Sleep_Hours  \
# 0            -1.332886        -0.489142      1.189247     0.988872
# 1             1.343591        -0.489142     -1.253359    -0.728531
# 2             0.451432        -0.489142     -0.904416    -1.455125
# 3             0.451432        -0.489142      1.189247    -0.266154
# 4            -0.440727         2.044397      0.142416    -0.596424
#
#    Gender_category  Assignments  DistancesToClusterCenter no.0  \
# 0         1.244488            1                       1.545040
# 1         1.244488            1                       1.196704
# ...

# %% [markdown]
# # Répartition des clusters dans le plan Age / IMC

# %%
sns.scatterplot(data=df, x='Age', y='IMC', hue='Assignments', palette='Set2')
plt.title("Répartition des clusters (Age vs IMC)")
plt.xlabel("Age")
plt.ylabel("IMC")
plt.legend(title="Cluster")
plt.show()

# %%
sns.scatterplot(data=df, x='Exercise_Freq', y='Diet_Quality', hue='Assignments', palette='Set2')
plt.title("Clusters : Exercice vs Qualité alimentaire")
plt.xlabel("Fréquence d'exercice")
plt.ylabel("Qualité du régime")
plt.show()

# %%
scatter_vars = [
    ("Age", "IMC"),
    ("Exercise_Freq", "Diet_Quality"),
    ("Stress_Level", "Sleep_Hours"),
    ("Alcohol_Consumption", "Stress_Level"),
    ("Age", "Stress_Level"),
    ("IMC", "Sleep_Hours")
]

# Création des sous-graphiques
ncols = 3
nrows = (len(scatter_vars) + ncols - 1) // ncols  # arrondi supérieur
fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(18, 10))
axes = axes.flatten()

# Boucle sur chaque paire de variables
for i, (x_var, y_var) in enumerate(scatter_vars):
    sns.scatterplot(
        data=df,
        x=x_var,
        y=y_var,
        hue='Assignments',
        palette='Set2',
        ax=axes[i],
        legend=False  # on désactive la légende pour éviter les répétitions
    )
    axes[i].set_title(f"{x_var} vs {y_var}")
    axes[i].set_xlabel(x_var)
    axes[i].set_ylabel(y_var)

# Légende globale
handles, labels = axes[0].get_legend_handles_labels()
fig.legend(handles, labels, title="Cluster", loc="lower center", ncol=2)

plt.tight_layout(rect=[0, 0.05, 1, 1])  # Laisse de la place poour la légende

plt.show()

# %% [markdown]
# # Conclusion il n'y a pas de séparation nette des groupes, il n'y a pas de cluster qui se dégage
